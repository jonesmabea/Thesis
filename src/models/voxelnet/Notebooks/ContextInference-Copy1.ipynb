# %%
! jupyter comet_ml enable

# %%
#!/usr/bin/env python
# -*- coding:UTF-8 -*-

# from comet_ml import Experiment
import glob
import argparse
import os
import time
import tensorflow as tf
from model import RPN3D
from config import cfg
from utils import *
from utils.kitti_loader import iterate_data, sample_test_data
import subprocess
# Out:
# /mnt/storage/home/ja17618/.conda/envs/vox/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /mnt/storage/home/ja17618/.conda/envs/vox/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
ctx = 'urban' 
tag = 'pre_trained_200'
output_path = 'urban_200' 
exp = 'urban'
bs=1
vis=False
GPU_AVAILABLE='1'
GPU_USE_COUNT=1

# %%
! nvidia-smi
# Out:
# Wed Aug  8 17:24:46 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 390.46                 Driver Version: 390.46                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:06:00.0 Off |                    0 |
# | N/A   34C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla P100-PCIE...  Off  | 00000000:86:00.0 Off |                    0 |
# | N/A   36C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
log = open('/mnt/storage/home/ja17618/vox_urbgpu3.out','w+')
log.flush()
path=''
dataset_dir = cfg.DATA_DIR
val_dir = os.path.join(cfg.CONTEXT_DIR, ctx)
save_model_dir = os.path.join('./save_model', tag)
total_inference_time = []
# experiment = Experiment(api_key="xXtJguCo8yFdU7dpjEpo6YbHw",project_name=exp)
# create output folder
os.makedirs(output_path, exist_ok=True)
os.makedirs(os.path.join(output_path, 'data'), exist_ok=True)
if vis:
    os.makedirs(os.path.join(output_path, 'vis'), exist_ok=True)

# process = subprocess.Popen('nvidia-smi -i 1 --format=csv -l 1 --query-gpu=index,timestamp,power.draw,utilization.gpu,clocks.current.sm,temperature.gpu,memory.used',stdout = log, shell=True)
with tf.Graph().as_default():
    gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=cfg.GPU_MEMORY_FRACTION,
                        visible_device_list=GPU_AVAILABLE,
                        allow_growth=True)

    config = tf.ConfigProto(
        gpu_options=gpu_options,
        device_count={
            "GPU": GPU_USE_COUNT,
        },
        allow_soft_placement=True,
        log_device_placement=False
    )

    with tf.Session(config=config) as sess:
        model = RPN3D(
            cls=cfg.DETECT_OBJ,
            single_batch_size=bs,
            avail_gpus=GPU_AVAILABLE
        )
        if tf.train.get_checkpoint_state(save_model_dir):
            print("Reading model parameters from %s" % save_model_dir)
            model.saver.restore(
                sess, tf.train.latest_checkpoint(save_model_dir))
        counter=0
#         with experiment.test():
        for batch in iterate_data(val_dir, shuffle=False, aug=False, is_testset=False, batch_size=bs * GPU_USE_COUNT, multi_gpu_sum=GPU_USE_COUNT):
#             experiment.log_metric("counter",counter)

            if vis:
                tags, results, front_images, bird_views, heatmaps = model.predict_step(sess, batch, summary=False, vis=True)
            else:
                inference_start_time=time.time()
                tags, results = model.predict_step(sess, batch, summary=False, vis=False)
                inference_time = time.time()-inference_start_time
                total_inference_time.append(inference_time)
            # ret: A, B
            # A: (N) tag
            # B: (N, N') (class, x, y, z, h, w, l, rz, score)
            for tag, result in zip(tags, results):
                of_path = os.path.join(output_path, 'data', tag + '.txt')
                with open(of_path, 'w+') as f:
                    labels = box3d_to_label([result[:, 1:8]], [result[:, 0]], [result[:, -1]], coordinate='lidar')[0]
                    for line in labels:
                        f.write(line)
#                     print('write out {} objects to {}'.format(len(labels), tag))
            # dump visualizations
            if vis:
                for tag, front_image, bird_view, heatmap in zip(tags, front_images, bird_views, heatmaps):
                    front_img_path = os.path.join( output_path, 'vis', tag + '_front.jpg'  )
                    bird_view_path = os.path.join( output_path, 'vis', tag + '_bv.jpg'  )
                    heatmap_path = os.path.join( output_path, 'vis', tag + '_heatmap.jpg'  )
                    cv2.imwrite( front_img_path, front_image )
                    cv2.imwrite( bird_view_path, bird_view )
                    cv2.imwrite( heatmap_path, heatmap )
            counter +=1
        
# process.kill()
# log.flush()
# log.close()
# Out:
# WARNING:tensorflow:From /mnt/storage/scratch/ja17618/voxelnet/model/group_pointcloud.py:67: calling reduce_max (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# INFO:tensorflow:Summary name Variable:0 is illegal; using Variable_0 instead.
# INFO:tensorflow:Summary name Variable_1:0 is illegal; using Variable_1_0 instead.
# INFO:tensorflow:Summary name Variable_2:0 is illegal; using Variable_2_0 instead.
# INFO:tensorflow:Summary name VFE-1/kernel:0 is illegal; using VFE-1/kernel_0 instead.
# INFO:tensorflow:Summary name VFE-1/bias:0 is illegal; using VFE-1/bias_0 instead.
# INFO:tensorflow:Summary name VFE-1/gamma:0 is illegal; using VFE-1/gamma_0 instead.
# INFO:tensorflow:Summary name VFE-1/beta:0 is illegal; using VFE-1/beta_0 instead.
# INFO:tensorflow:Summary name VFE-1/moving_mean:0 is illegal; using VFE-1/moving_mean_0 instead.
# INFO:tensorflow:Summary name VFE-1/moving_variance:0 is illegal; using VFE-1/moving_variance_0 instead.
# INFO:tensorflow:Summary name VFE-2/kernel:0 is illegal; using VFE-2/kernel_0 instead.
# INFO:tensorflow:Summary name VFE-2/bias:0 is illegal; using VFE-2/bias_0 instead.
# INFO:tensorflow:Summary name VFE-2/gamma:0 is illegal; using VFE-2/gamma_0 instead.
# INFO:tensorflow:Summary name VFE-2/beta:0 is illegal; using VFE-2/beta_0 instead.
# INFO:tensorflow:Summary name VFE-2/moving_mean:0 is illegal; using VFE-2/moving_mean_0 instead.
# INFO:tensorflow:Summary name VFE-2/moving_variance:0 is illegal; using VFE-2/moving_variance_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv1/kernel:0 is illegal; using MiddleAndRPN_/conv1/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv1/bias:0 is illegal; using MiddleAndRPN_/conv1/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv1/gamma:0 is illegal; using MiddleAndRPN_/conv1/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv1/beta:0 is illegal; using MiddleAndRPN_/conv1/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv1/moving_mean:0 is illegal; using MiddleAndRPN_/conv1/moving_mean_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv1/moving_variance:0 is illegal; using MiddleAndRPN_/conv1/moving_variance_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv2/kernel:0 is illegal; using MiddleAndRPN_/conv2/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv2/bias:0 is illegal; using MiddleAndRPN_/conv2/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv2/gamma:0 is illegal; using MiddleAndRPN_/conv2/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv2/beta:0 is illegal; using MiddleAndRPN_/conv2/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv2/moving_mean:0 is illegal; using MiddleAndRPN_/conv2/moving_mean_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv2/moving_variance:0 is illegal; using MiddleAndRPN_/conv2/moving_variance_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv3/kernel:0 is illegal; using MiddleAndRPN_/conv3/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv3/bias:0 is illegal; using MiddleAndRPN_/conv3/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv3/gamma:0 is illegal; using MiddleAndRPN_/conv3/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv3/beta:0 is illegal; using MiddleAndRPN_/conv3/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv3/moving_mean:0 is illegal; using MiddleAndRPN_/conv3/moving_mean_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv3/moving_variance:0 is illegal; using MiddleAndRPN_/conv3/moving_variance_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv4/kernel:0 is illegal; using MiddleAndRPN_/conv4/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv4/bias:0 is illegal; using MiddleAndRPN_/conv4/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv4/gamma:0 is illegal; using MiddleAndRPN_/conv4/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv4/beta:0 is illegal; using MiddleAndRPN_/conv4/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv4/moving_mean:0 is illegal; using MiddleAndRPN_/conv4/moving_mean_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv4/moving_variance:0 is illegal; using MiddleAndRPN_/conv4/moving_variance_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv5/kernel:0 is illegal; using MiddleAndRPN_/conv5/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv5/bias:0 is illegal; using MiddleAndRPN_/conv5/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv5/gamma:0 is illegal; using MiddleAndRPN_/conv5/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv5/beta:0 is illegal; using MiddleAndRPN_/conv5/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv5/moving_mean:0 is illegal; using MiddleAndRPN_/conv5/moving_mean_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv5/moving_variance:0 is illegal; using MiddleAndRPN_/conv5/moving_variance_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv6/kernel:0 is illegal; using MiddleAndRPN_/conv6/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv6/bias:0 is illegal; using MiddleAndRPN_/conv6/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv6/gamma:0 is illegal; using MiddleAndRPN_/conv6/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv6/beta:0 is illegal; using MiddleAndRPN_/conv6/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv6/moving_mean:0 is illegal; using MiddleAndRPN_/conv6/moving_mean_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv6/moving_variance:0 is illegal; using MiddleAndRPN_/conv6/moving_variance_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv7/kernel:0 is illegal; using MiddleAndRPN_/conv7/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv7/bias:0 is illegal; using MiddleAndRPN_/conv7/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv7/gamma:0 is illegal; using MiddleAndRPN_/conv7/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv7/beta:0 is illegal; using MiddleAndRPN_/conv7/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv7/moving_mean:0 is illegal; using MiddleAndRPN_/conv7/moving_mean_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv7/moving_variance:0 is illegal; using MiddleAndRPN_/conv7/moving_variance_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv1/kernel:0 is illegal; using MiddleAndRPN_/deconv1/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv1/bias:0 is illegal; using MiddleAndRPN_/deconv1/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv1/gamma:0 is illegal; using MiddleAndRPN_/deconv1/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv1/beta:0 is illegal; using MiddleAndRPN_/deconv1/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv1/moving_mean:0 is illegal; using MiddleAndRPN_/deconv1/moving_mean_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv1/moving_variance:0 is illegal; using MiddleAndRPN_/deconv1/moving_variance_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv8/kernel:0 is illegal; using MiddleAndRPN_/conv8/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv8/bias:0 is illegal; using MiddleAndRPN_/conv8/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv8/gamma:0 is illegal; using MiddleAndRPN_/conv8/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv8/beta:0 is illegal; using MiddleAndRPN_/conv8/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv8/moving_mean:0 is illegal; using MiddleAndRPN_/conv8/moving_mean_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv8/moving_variance:0 is illegal; using MiddleAndRPN_/conv8/moving_variance_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv9/kernel:0 is illegal; using MiddleAndRPN_/conv9/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv9/bias:0 is illegal; using MiddleAndRPN_/conv9/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv9/gamma:0 is illegal; using MiddleAndRPN_/conv9/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv9/beta:0 is illegal; using MiddleAndRPN_/conv9/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv9/moving_mean:0 is illegal; using MiddleAndRPN_/conv9/moving_mean_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv9/moving_variance:0 is illegal; using MiddleAndRPN_/conv9/moving_variance_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv10/kernel:0 is illegal; using MiddleAndRPN_/conv10/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv10/bias:0 is illegal; using MiddleAndRPN_/conv10/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv10/gamma:0 is illegal; using MiddleAndRPN_/conv10/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv10/beta:0 is illegal; using MiddleAndRPN_/conv10/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv10/moving_mean:0 is illegal; using MiddleAndRPN_/conv10/moving_mean_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv10/moving_variance:0 is illegal; using MiddleAndRPN_/conv10/moving_variance_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv11/kernel:0 is illegal; using MiddleAndRPN_/conv11/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv11/bias:0 is illegal; using MiddleAndRPN_/conv11/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv11/gamma:0 is illegal; using MiddleAndRPN_/conv11/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv11/beta:0 is illegal; using MiddleAndRPN_/conv11/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv11/moving_mean:0 is illegal; using MiddleAndRPN_/conv11/moving_mean_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv11/moving_variance:0 is illegal; using MiddleAndRPN_/conv11/moving_variance_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv12/kernel:0 is illegal; using MiddleAndRPN_/conv12/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv12/bias:0 is illegal; using MiddleAndRPN_/conv12/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv12/gamma:0 is illegal; using MiddleAndRPN_/conv12/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv12/beta:0 is illegal; using MiddleAndRPN_/conv12/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv12/moving_mean:0 is illegal; using MiddleAndRPN_/conv12/moving_mean_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv12/moving_variance:0 is illegal; using MiddleAndRPN_/conv12/moving_variance_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv13/kernel:0 is illegal; using MiddleAndRPN_/conv13/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv13/bias:0 is illegal; using MiddleAndRPN_/conv13/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv13/gamma:0 is illegal; using MiddleAndRPN_/conv13/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv13/beta:0 is illegal; using MiddleAndRPN_/conv13/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv13/moving_mean:0 is illegal; using MiddleAndRPN_/conv13/moving_mean_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv13/moving_variance:0 is illegal; using MiddleAndRPN_/conv13/moving_variance_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv2/kernel:0 is illegal; using MiddleAndRPN_/deconv2/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv2/bias:0 is illegal; using MiddleAndRPN_/deconv2/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv2/gamma:0 is illegal; using MiddleAndRPN_/deconv2/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv2/beta:0 is illegal; using MiddleAndRPN_/deconv2/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv2/moving_mean:0 is illegal; using MiddleAndRPN_/deconv2/moving_mean_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv2/moving_variance:0 is illegal; using MiddleAndRPN_/deconv2/moving_variance_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv14/kernel:0 is illegal; using MiddleAndRPN_/conv14/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv14/bias:0 is illegal; using MiddleAndRPN_/conv14/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv14/gamma:0 is illegal; using MiddleAndRPN_/conv14/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv14/beta:0 is illegal; using MiddleAndRPN_/conv14/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv14/moving_mean:0 is illegal; using MiddleAndRPN_/conv14/moving_mean_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv14/moving_variance:0 is illegal; using MiddleAndRPN_/conv14/moving_variance_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv15/kernel:0 is illegal; using MiddleAndRPN_/conv15/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv15/bias:0 is illegal; using MiddleAndRPN_/conv15/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv15/gamma:0 is illegal; using MiddleAndRPN_/conv15/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv15/beta:0 is illegal; using MiddleAndRPN_/conv15/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv15/moving_mean:0 is illegal; using MiddleAndRPN_/conv15/moving_mean_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv15/moving_variance:0 is illegal; using MiddleAndRPN_/conv15/moving_variance_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv16/kernel:0 is illegal; using MiddleAndRPN_/conv16/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv16/bias:0 is illegal; using MiddleAndRPN_/conv16/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv16/gamma:0 is illegal; using MiddleAndRPN_/conv16/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv16/beta:0 is illegal; using MiddleAndRPN_/conv16/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv16/moving_mean:0 is illegal; using MiddleAndRPN_/conv16/moving_mean_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv16/moving_variance:0 is illegal; using MiddleAndRPN_/conv16/moving_variance_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv17/kernel:0 is illegal; using MiddleAndRPN_/conv17/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv17/bias:0 is illegal; using MiddleAndRPN_/conv17/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv17/gamma:0 is illegal; using MiddleAndRPN_/conv17/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv17/beta:0 is illegal; using MiddleAndRPN_/conv17/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv17/moving_mean:0 is illegal; using MiddleAndRPN_/conv17/moving_mean_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv17/moving_variance:0 is illegal; using MiddleAndRPN_/conv17/moving_variance_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv18/kernel:0 is illegal; using MiddleAndRPN_/conv18/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv18/bias:0 is illegal; using MiddleAndRPN_/conv18/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv18/gamma:0 is illegal; using MiddleAndRPN_/conv18/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv18/beta:0 is illegal; using MiddleAndRPN_/conv18/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv18/moving_mean:0 is illegal; using MiddleAndRPN_/conv18/moving_mean_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv18/moving_variance:0 is illegal; using MiddleAndRPN_/conv18/moving_variance_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv19/kernel:0 is illegal; using MiddleAndRPN_/conv19/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv19/bias:0 is illegal; using MiddleAndRPN_/conv19/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv19/gamma:0 is illegal; using MiddleAndRPN_/conv19/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv19/beta:0 is illegal; using MiddleAndRPN_/conv19/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv19/moving_mean:0 is illegal; using MiddleAndRPN_/conv19/moving_mean_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv19/moving_variance:0 is illegal; using MiddleAndRPN_/conv19/moving_variance_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv3/kernel:0 is illegal; using MiddleAndRPN_/deconv3/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv3/bias:0 is illegal; using MiddleAndRPN_/deconv3/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv3/gamma:0 is illegal; using MiddleAndRPN_/deconv3/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv3/beta:0 is illegal; using MiddleAndRPN_/deconv3/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv3/moving_mean:0 is illegal; using MiddleAndRPN_/deconv3/moving_mean_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv3/moving_variance:0 is illegal; using MiddleAndRPN_/deconv3/moving_variance_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv20/kernel:0 is illegal; using MiddleAndRPN_/conv20/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv20/bias:0 is illegal; using MiddleAndRPN_/conv20/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv21/kernel:0 is illegal; using MiddleAndRPN_/conv21/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv21/bias:0 is illegal; using MiddleAndRPN_/conv21/bias_0 instead.
# INFO:tensorflow:Summary name VFE-1/kernel:0 is illegal; using VFE-1/kernel_0 instead.
# INFO:tensorflow:Summary name VFE-1/bias:0 is illegal; using VFE-1/bias_0 instead.
# INFO:tensorflow:Summary name VFE-1/gamma:0 is illegal; using VFE-1/gamma_0 instead.
# INFO:tensorflow:Summary name VFE-1/beta:0 is illegal; using VFE-1/beta_0 instead.
# INFO:tensorflow:Summary name VFE-2/kernel:0 is illegal; using VFE-2/kernel_0 instead.
# INFO:tensorflow:Summary name VFE-2/bias:0 is illegal; using VFE-2/bias_0 instead.
# INFO:tensorflow:Summary name VFE-2/gamma:0 is illegal; using VFE-2/gamma_0 instead.
# INFO:tensorflow:Summary name VFE-2/beta:0 is illegal; using VFE-2/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv1/kernel:0 is illegal; using MiddleAndRPN_/conv1/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv1/bias:0 is illegal; using MiddleAndRPN_/conv1/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv1/gamma:0 is illegal; using MiddleAndRPN_/conv1/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv1/beta:0 is illegal; using MiddleAndRPN_/conv1/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv2/kernel:0 is illegal; using MiddleAndRPN_/conv2/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv2/bias:0 is illegal; using MiddleAndRPN_/conv2/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv2/gamma:0 is illegal; using MiddleAndRPN_/conv2/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv2/beta:0 is illegal; using MiddleAndRPN_/conv2/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv3/kernel:0 is illegal; using MiddleAndRPN_/conv3/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv3/bias:0 is illegal; using MiddleAndRPN_/conv3/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv3/gamma:0 is illegal; using MiddleAndRPN_/conv3/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv3/beta:0 is illegal; using MiddleAndRPN_/conv3/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv4/kernel:0 is illegal; using MiddleAndRPN_/conv4/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv4/bias:0 is illegal; using MiddleAndRPN_/conv4/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv4/gamma:0 is illegal; using MiddleAndRPN_/conv4/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv4/beta:0 is illegal; using MiddleAndRPN_/conv4/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv5/kernel:0 is illegal; using MiddleAndRPN_/conv5/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv5/bias:0 is illegal; using MiddleAndRPN_/conv5/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv5/gamma:0 is illegal; using MiddleAndRPN_/conv5/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv5/beta:0 is illegal; using MiddleAndRPN_/conv5/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv6/kernel:0 is illegal; using MiddleAndRPN_/conv6/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv6/bias:0 is illegal; using MiddleAndRPN_/conv6/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv6/gamma:0 is illegal; using MiddleAndRPN_/conv6/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv6/beta:0 is illegal; using MiddleAndRPN_/conv6/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv7/kernel:0 is illegal; using MiddleAndRPN_/conv7/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv7/bias:0 is illegal; using MiddleAndRPN_/conv7/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv7/gamma:0 is illegal; using MiddleAndRPN_/conv7/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv7/beta:0 is illegal; using MiddleAndRPN_/conv7/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv1/kernel:0 is illegal; using MiddleAndRPN_/deconv1/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv1/bias:0 is illegal; using MiddleAndRPN_/deconv1/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv1/gamma:0 is illegal; using MiddleAndRPN_/deconv1/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv1/beta:0 is illegal; using MiddleAndRPN_/deconv1/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv8/kernel:0 is illegal; using MiddleAndRPN_/conv8/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv8/bias:0 is illegal; using MiddleAndRPN_/conv8/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv8/gamma:0 is illegal; using MiddleAndRPN_/conv8/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv8/beta:0 is illegal; using MiddleAndRPN_/conv8/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv9/kernel:0 is illegal; using MiddleAndRPN_/conv9/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv9/bias:0 is illegal; using MiddleAndRPN_/conv9/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv9/gamma:0 is illegal; using MiddleAndRPN_/conv9/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv9/beta:0 is illegal; using MiddleAndRPN_/conv9/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv10/kernel:0 is illegal; using MiddleAndRPN_/conv10/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv10/bias:0 is illegal; using MiddleAndRPN_/conv10/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv10/gamma:0 is illegal; using MiddleAndRPN_/conv10/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv10/beta:0 is illegal; using MiddleAndRPN_/conv10/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv11/kernel:0 is illegal; using MiddleAndRPN_/conv11/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv11/bias:0 is illegal; using MiddleAndRPN_/conv11/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv11/gamma:0 is illegal; using MiddleAndRPN_/conv11/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv11/beta:0 is illegal; using MiddleAndRPN_/conv11/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv12/kernel:0 is illegal; using MiddleAndRPN_/conv12/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv12/bias:0 is illegal; using MiddleAndRPN_/conv12/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv12/gamma:0 is illegal; using MiddleAndRPN_/conv12/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv12/beta:0 is illegal; using MiddleAndRPN_/conv12/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv13/kernel:0 is illegal; using MiddleAndRPN_/conv13/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv13/bias:0 is illegal; using MiddleAndRPN_/conv13/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv13/gamma:0 is illegal; using MiddleAndRPN_/conv13/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv13/beta:0 is illegal; using MiddleAndRPN_/conv13/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv2/kernel:0 is illegal; using MiddleAndRPN_/deconv2/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv2/bias:0 is illegal; using MiddleAndRPN_/deconv2/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv2/gamma:0 is illegal; using MiddleAndRPN_/deconv2/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv2/beta:0 is illegal; using MiddleAndRPN_/deconv2/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv14/kernel:0 is illegal; using MiddleAndRPN_/conv14/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv14/bias:0 is illegal; using MiddleAndRPN_/conv14/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv14/gamma:0 is illegal; using MiddleAndRPN_/conv14/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv14/beta:0 is illegal; using MiddleAndRPN_/conv14/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv15/kernel:0 is illegal; using MiddleAndRPN_/conv15/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv15/bias:0 is illegal; using MiddleAndRPN_/conv15/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv15/gamma:0 is illegal; using MiddleAndRPN_/conv15/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv15/beta:0 is illegal; using MiddleAndRPN_/conv15/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv16/kernel:0 is illegal; using MiddleAndRPN_/conv16/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv16/bias:0 is illegal; using MiddleAndRPN_/conv16/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv16/gamma:0 is illegal; using MiddleAndRPN_/conv16/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv16/beta:0 is illegal; using MiddleAndRPN_/conv16/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv17/kernel:0 is illegal; using MiddleAndRPN_/conv17/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv17/bias:0 is illegal; using MiddleAndRPN_/conv17/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv17/gamma:0 is illegal; using MiddleAndRPN_/conv17/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv17/beta:0 is illegal; using MiddleAndRPN_/conv17/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv18/kernel:0 is illegal; using MiddleAndRPN_/conv18/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv18/bias:0 is illegal; using MiddleAndRPN_/conv18/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv18/gamma:0 is illegal; using MiddleAndRPN_/conv18/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv18/beta:0 is illegal; using MiddleAndRPN_/conv18/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv19/kernel:0 is illegal; using MiddleAndRPN_/conv19/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv19/bias:0 is illegal; using MiddleAndRPN_/conv19/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv19/gamma:0 is illegal; using MiddleAndRPN_/conv19/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv19/beta:0 is illegal; using MiddleAndRPN_/conv19/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv3/kernel:0 is illegal; using MiddleAndRPN_/deconv3/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv3/bias:0 is illegal; using MiddleAndRPN_/deconv3/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv3/gamma:0 is illegal; using MiddleAndRPN_/deconv3/gamma_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/deconv3/beta:0 is illegal; using MiddleAndRPN_/deconv3/beta_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv20/kernel:0 is illegal; using MiddleAndRPN_/conv20/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv20/bias:0 is illegal; using MiddleAndRPN_/conv20/bias_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv21/kernel:0 is illegal; using MiddleAndRPN_/conv21/kernel_0 instead.
# INFO:tensorflow:Summary name MiddleAndRPN_/conv21/bias:0 is illegal; using MiddleAndRPN_/conv21/bias_0 instead.
# Reading model parameters from ./save_model/pre_trained_200
# INFO:tensorflow:Restoring parameters from ./save_model/pre_trained_200/checkpoint-00184673
# predict ['000000']
# predict ['000010']
# predict ['000011']
# predict ['000012']
# predict ['000026']
# predict ['000032']
# predict ['000036']
# predict ['000041']
# predict ['000046']
# predict ['000054']
# predict ['000067']
# predict ['000069']
# predict ['000074']
# predict ['000079']
# predict ['000085']
# predict ['000086']
# predict ['000092']
# predict ['000095']
# predict ['000112']
# predict ['000113']
# predict ['000121']
# predict ['000127']
# predict ['000131']
# predict ['000145']
# predict ['000146']
# predict ['000148']
# predict ['000157']
# predict ['000158']
# predict ['000165']
# predict ['000172']
# predict ['000200']
# predict ['000214']
# predict ['000228']
# predict ['000238']
# predict ['000244']
# predict ['000245']
# predict ['000258']
# predict ['000264']
# predict ['000274']
# predict ['000275']
# predict ['000276']
# predict ['000285']
# predict ['000288']
# predict ['000296']
# predict ['000298']
# predict ['000300']
# predict ['000303']
# predict ['000310']
# predict ['000317']
# predict ['000326']
# predict ['000339']
# predict ['000342']
# predict ['000367']
# predict ['000374']
# predict ['000380']
# predict ['000384']
# predict ['000390']
# predict ['000416']
# predict ['000417']
# predict ['000421']
# predict ['000432']
# predict ['000433']
# predict ['000438']
# predict ['000441']
# predict ['000442']
# predict ['000444']
# predict ['000456']
# predict ['000465']
# predict ['000483']
# predict ['000497']
# predict ['000505']
# predict ['000507']
# predict ['000513']
# predict ['000516']
# predict ['000518']
# predict ['000520']
# predict ['000523']
# predict ['000531']
# predict ['000532']
# predict ['000534']
# predict ['000535']
# predict ['000538']
# predict ['000549']
# predict ['000552']
# predict ['000553']
# predict ['000563']
# predict ['000587']
# predict ['000594']
# predict ['000596']
# predict ['000606']
# predict ['000622']
# predict ['000623']
# predict ['000633']
# predict ['000637']
# predict ['000646']
# predict ['000649']
# predict ['000662']
# predict ['000671']
# predict ['000675']
# predict ['000680']
# predict ['000685']
# predict ['000688']
# predict ['000689']
# predict ['000695']
# predict ['000701']
# predict ['000703']
# predict ['000714']
# predict ['000720']
# predict ['000733']
# predict ['000738']
# predict ['000757']
# predict ['000770']
# predict ['000814']
# predict ['000817']
# predict ['000827']
# predict ['000845']
# predict ['000856']
# predict ['000857']
# predict ['000868']
# predict ['000870']
# predict ['000882']
# predict ['000892']
# predict ['000895']
# predict ['000900']
# predict ['000910']
# predict ['000913']
# predict ['000921']
# predict ['000927']
# predict ['000935']
# predict ['000945']
# predict ['000946']
# predict ['000972']
# predict ['000975']
# predict ['000977']
# predict ['000980']
# predict ['000992']
# predict ['000996']
# predict ['001005']
# predict ['001030']
# predict ['001031']
# predict ['001038']
# predict ['001040']
# predict ['001041']
# predict ['001045']
# predict ['001048']
# predict ['001059']
# predict ['001060']
# predict ['001061']
# predict ['001074']
# predict ['001079']
# predict ['001080']
# predict ['001112']
# predict ['001119']
# predict ['001161']
# predict ['001169']
# predict ['001170']
# predict ['001174']
# predict ['001190']
# predict ['001200']
# predict ['001215']
# predict ['001223']
# predict ['001231']
# predict ['001233']
# predict ['001248']
# predict ['001256']
# predict ['001276']
# predict ['001277']
# predict ['001288']
# predict ['001297']
# predict ['001300']
# predict ['001301']
# predict ['001310']
# predict ['001311']
# predict ['001313']
# predict ['001338']
# predict ['001343']
# predict ['001354']
# predict ['001357']
# predict ['001366']
# predict ['001370']
# predict ['001371']
# predict ['001393']
# predict ['001394']
# predict ['001401']
# predict ['001406']
# predict ['001420']
# predict ['001423']
# predict ['001426']
# predict ['001428']
# predict ['001434']
# predict ['001456']
# predict ['001459']
# predict ['001467']
# predict ['001473']
# predict ['001474']
# predict ['001476']
# predict ['001494']
# predict ['001509']
# predict ['001518']
# predict ['001544']
# predict ['001548']
# predict ['001551']
# predict ['001554']
# predict ['001568']
# predict ['001572']
# predict ['001580']
# predict ['001607']
# predict ['001608']
# predict ['001609']
# predict ['001612']
# predict ['001614']
# predict ['001620']
# predict ['001622']
# predict ['001624']
# predict ['001632']
# predict ['001672']
# predict ['001673']
# predict ['001674']
# predict ['001681']
# predict ['001690']
# predict ['001691']
# predict ['001692']
# predict ['001696']
# predict ['001708']
# predict ['001716']
# predict ['001720']
# predict ['001744']
# predict ['001760']
# predict ['001767']
# predict ['001770']
# predict ['001777']
# predict ['001803']
# predict ['001819']
# predict ['001837']
# predict ['001841']
# predict ['001857']
# predict ['001864']
# predict ['001870']
# predict ['001873']
# predict ['001879']
# predict ['001896']
# predict ['001903']
# predict ['001912']
# predict ['001913']
# predict ['001917']
# predict ['001958']
# predict ['001962']
# predict ['001968']
# predict ['001970']
# predict ['001981']
# predict ['001988']
# predict ['001998']
# predict ['002005']
# predict ['002009']
# predict ['002016']
# predict ['002024']
# predict ['002026']
# predict ['002030']
# predict ['002032']
# predict ['002033']
# predict ['002039']
# predict ['002041']
# predict ['002047']
# predict ['002060']
# predict ['002067']
# predict ['002080']
# predict ['002088']
# predict ['002095']
# predict ['002099']
# predict ['002105']
# predict ['002106']
# predict ['002117']
# predict ['002134']
# predict ['002141']
# predict ['002144']
# predict ['002155']
# predict ['002157']
# predict ['002167']
# predict ['002172']
# predict ['002194']
# predict ['002198']
# predict ['002205']
# predict ['002212']
# predict ['002221']
# predict ['002226']
# predict ['002227']
# predict ['002230']
# predict ['002231']
# predict ['002236']
# predict ['002247']
# predict ['002253']
# predict ['002256']
# predict ['002263']
# predict ['002264']
# predict ['002265']
# predict ['002275']
# predict ['002285']
# predict ['002288']
# predict ['002309']
# predict ['002322']
# predict ['002324']
# predict ['002342']
# predict ['002349']
# predict ['002350']
# predict ['002352']
# predict ['002364']
# predict ['002377']
# predict ['002390']
# predict ['002395']
# predict ['002400']
# predict ['002413']
# predict ['002426']
# predict ['002427']
# predict ['002431']
# predict ['002435']
# predict ['002436']
# predict ['002443']
# predict ['002444']
# predict ['002448']
# predict ['002451']
# predict ['002453']
# predict ['002459']
# predict ['002471']
# predict ['002472']
# predict ['002485']
# predict ['002493']
# predict ['002494']
# predict ['002496']
# predict ['002501']
# predict ['002510']
# predict ['002517']
# predict ['002527']
# predict ['002537']
# predict ['002547']
# predict ['002553']
# predict ['002589']
# predict ['002605']
# predict ['002611']
# predict ['002614']
# predict ['002652']
# predict ['002662']
# predict ['002671']
# predict ['002672']
# predict ['002682']
# predict ['002687']
# predict ['002689']
# predict ['002697']
# predict ['002701']
# predict ['002703']
# predict ['002704']
# predict ['002705']
# predict ['002708']
# predict ['002723']
# predict ['002738']
# predict ['002743']
# predict ['002762']
# predict ['002768']
# predict ['002769']
# predict ['002780']
# predict ['002790']
# predict ['002792']
# predict ['002798']
# predict ['002799']
# predict ['002802']
# predict ['002807']
# predict ['002813']
# predict ['002817']
# predict ['002819']
# predict ['002822']
# predict ['002825']
# predict ['002829']
# predict ['002834']
# predict ['002837']
# predict ['002838']
# predict ['002855']
# predict ['002857']
# predict ['002859']
# predict ['002868']
# predict ['002869']
# predict ['002870']
# predict ['002874']
# predict ['002899']
# predict ['002915']
# predict ['002926']
# predict ['002938']
# predict ['002949']
# predict ['002956']
# predict ['002969']
# predict ['002970']
# predict ['002983']
# predict ['002987']
# predict ['003008']
# predict ['003013']
# predict ['003014']
# predict ['003016']
# predict ['003018']
# predict ['003020']
# predict ['003023']
# predict ['003026']
# predict ['003036']
# predict ['003039']
# predict ['003041']
# predict ['003064']
# predict ['003070']
# predict ['003075']
# predict ['003078']
# predict ['003081']
# predict ['003083']
# predict ['003086']
# predict ['003095']
# predict ['003097']
# predict ['003104']
# predict ['003108']
# predict ['003115']
# predict ['003120']
# predict ['003121']
# predict ['003123']
# predict ['003130']
# predict ['003140']
# predict ['003147']
# predict ['003151']
# predict ['003157']
# predict ['003163']
# predict ['003168']
# predict ['003169']
# predict ['003178']
# predict ['003185']
# predict ['003212']
# predict ['003215']
# predict ['003235']
# predict ['003237']
# predict ['003244']
# predict ['003245']
# predict ['003256']
# predict ['003261']
# predict ['003262']
# predict ['003267']
# predict ['003277']
# predict ['003279']
# predict ['003287']
# predict ['003299']
# predict ['003303']
# predict ['003311']
# predict ['003317']
# predict ['003320']
# predict ['003321']
# predict ['003326']
# predict ['003327']
# predict ['003329']
# predict ['003333']
# predict ['003345']
# predict ['003349']
# predict ['003356']
# predict ['003359']
# predict ['003362']
# predict ['003369']
# predict ['003380']
# predict ['003381']
# predict ['003384']
# predict ['003418']
# predict ['003424']
# predict ['003436']
# predict ['003438']
# predict ['003441']
# predict ['003454']
# predict ['003457']
# predict ['003458']
# predict ['003476']
# predict ['003477']
# predict ['003485']
# predict ['003498']
# predict ['003507']
# predict ['003508']
# predict ['003509']
# predict ['003514']
# predict ['003516']
# predict ['003518']
# predict ['003526']
# predict ['003534']
# predict ['003540']
# predict ['003541']
# predict ['003542']
# predict ['003549']
# predict ['003555']
# predict ['003565']
# predict ['003575']
# predict ['003576']
# predict ['003581']
# predict ['003585']
# predict ['003586']
# predict ['003589']
# predict ['003590']
# predict ['003593']
# predict ['003606']
# predict ['003613']
# predict ['003625']
# predict ['003628']
# predict ['003642']
# predict ['003644']
# predict ['003646']
# predict ['003664']
# predict ['003666']
# predict ['003675']
# predict ['003685']
# predict ['003694']
# predict ['003700']
# predict ['003706']
# predict ['003721']
# predict ['003725']
# predict ['003744']
# predict ['003749']
# predict ['003758']
# predict ['003760']
# predict ['003765']
# predict ['003770']
# predict ['003776']
# predict ['003785']
# predict ['003786']
# predict ['003790']
# predict ['003796']
# predict ['003806']
# predict ['003810']
# predict ['003815']
# predict ['003818']
# predict ['003823']
# predict ['003838']
# predict ['003846']
# predict ['003857']
# predict ['003863']
# predict ['003868']
# predict ['003875']
# predict ['003882']
# predict ['003887']
# predict ['003906']
# predict ['003908']
# predict ['003911']
# predict ['003921']
# predict ['003922']
# predict ['003927']
# predict ['003935']
# predict ['003942']
# predict ['003951']
# predict ['003953']
# predict ['003955']
# predict ['003960']
# predict ['003973']
# predict ['003985']
# predict ['003989']
# predict ['003991']
# predict ['003999']
# predict ['004012']
# predict ['004014']
# predict ['004015']
# predict ['004017']
# predict ['004018']
# predict ['004023']
# predict ['004052']
# predict ['004053']
# predict ['004062']
# predict ['004080']
# predict ['004084']
# predict ['004086']
# predict ['004090']
# predict ['004094']
# predict ['004102']
# predict ['004103']
# predict ['004114']
# predict ['004135']
# predict ['004139']
# predict ['004166']
# predict ['004167']
# predict ['004169']
# predict ['004177']
# predict ['004192']
# predict ['004194']
# predict ['004204']
# predict ['004218']
# predict ['004219']
# predict ['004229']
# predict ['004233']
# predict ['004240']
# predict ['004245']
# predict ['004261']
# predict ['004262']
# predict ['004264']
# predict ['004265']
# predict ['004267']
# predict ['004269']
# predict ['004283']
# predict ['004296']
# predict ['004308']
# predict ['004317']
# predict ['004322']
# predict ['004325']
# predict ['004334']
# predict ['004341']
# predict ['004351']
# predict ['004361']
# predict ['004379']
# predict ['004387']
# predict ['004389']
# predict ['004405']
# predict ['004408']
# predict ['004413']
# predict ['004417']
# predict ['004431']
# predict ['004436']
# predict ['004442']
# predict ['004449']
# predict ['004466']
# predict ['004468']
# predict ['004479']
# predict ['004484']
# predict ['004495']
# predict ['004500']
# predict ['004503']
# predict ['004512']
# predict ['004514']
# predict ['004533']
# predict ['004543']
# predict ['004546']
# predict ['004558']
# predict ['004565']
# predict ['004577']
# predict ['004583']
# predict ['004590']
# predict ['004593']
# predict ['004595']
# predict ['004600']
# predict ['004617']
# predict ['004635']
# predict ['004637']
# predict ['004639']
# predict ['004674']
# predict ['004675']
# predict ['004677']
# predict ['004696']
# predict ['004704']
# predict ['004723']
# predict ['004728']
# predict ['004729']
# predict ['004731']
# predict ['004736']
# predict ['004749']
# predict ['004750']
# predict ['004751']
# predict ['004754']
# predict ['004758']
# predict ['004771']
# predict ['004772']
# predict ['004774']
# predict ['004780']
# predict ['004781']
# predict ['004784']
# predict ['004785']
# predict ['004793']
# predict ['004798']
# predict ['004802']
# predict ['004808']
# predict ['004812']
# predict ['004836']
# predict ['004837']
# predict ['004841']
# predict ['004842']
# predict ['004845']
# predict ['004854']
# predict ['004857']
# predict ['004869']
# predict ['004882']
# predict ['004894']
# predict ['004897']
# predict ['004899']
# predict ['004911']
# predict ['004912']
# predict ['004916']
# predict ['004919']
# predict ['004923']
# predict ['004937']
# predict ['004945']
# predict ['004950']
# predict ['004955']
# predict ['004964']
# predict ['004969']
# predict ['004972']
# predict ['004973']
# predict ['004980']
# predict ['004987']
# predict ['004997']
# predict ['005011']
# predict ['005018']
# predict ['005025']
# predict ['005027']
# predict ['005031']
# predict ['005039']
# predict ['005043']
# predict ['005051']
# predict ['005060']
# predict ['005061']
# predict ['005069']
# predict ['005071']
# predict ['005076']
# predict ['005085']
# predict ['005096']
# predict ['005097']
# predict ['005098']
# predict ['005099']
# predict ['005106']
# predict ['005111']
# predict ['005114']
# predict ['005118']
# predict ['005119']
# predict ['005126']
# predict ['005132']
# predict ['005134']
# predict ['005137']
# predict ['005142']
# predict ['005146']
# predict ['005152']
# predict ['005160']
# predict ['005169']
# predict ['005193']
# predict ['005196']
# predict ['005208']
# predict ['005209']
# predict ['005212']
# predict ['005215']
# predict ['005220']
# predict ['005232']
# predict ['005235']
# predict ['005247']
# predict ['005250']
# predict ['005259']
# predict ['005261']
# predict ['005269']
# predict ['005277']
# predict ['005278']
# predict ['005294']
# predict ['005301']
# predict ['005340']
# predict ['005344']
# predict ['005346']
# predict ['005352']
# predict ['005354']
# predict ['005357']
# predict ['005362']
# predict ['005364']
# predict ['005367']
# predict ['005388']
# predict ['005397']
# predict ['005403']
# predict ['005406']
# predict ['005410']
# predict ['005411']
# predict ['005412']
# predict ['005417']
# predict ['005419']
# predict ['005438']
# predict ['005454']
# predict ['005455']
# predict ['005475']
# predict ['005490']
# predict ['005492']
# predict ['005497']
# predict ['005503']
# predict ['005506']
# predict ['005507']
# predict ['005512']
# predict ['005519']
# predict ['005521']
# predict ['005553']
# predict ['005568']
# predict ['005569']
# predict ['005578']
# predict ['005591']
# predict ['005594']
# predict ['005598']
# predict ['005609']
# predict ['005615']
# predict ['005622']
# predict ['005626']
# predict ['005627']
# predict ['005628']
# predict ['005632']
# predict ['005645']
# predict ['005667']
# predict ['005671']
# predict ['005674']
# predict ['005675']
# predict ['005679']
# predict ['005682']
# predict ['005684']
# predict ['005688']
# predict ['005691']
# predict ['005718']
# predict ['005732']
# predict ['005738']
# predict ['005750']
# predict ['005758']
# predict ['005771']
# predict ['005775']
# predict ['005776']
# predict ['005778']
# predict ['005779']
# predict ['005780']
# predict ['005795']
# predict ['005798']
# predict ['005804']
# predict ['005813']
# predict ['005814']
# predict ['005816']
# predict ['005824']
# predict ['005830']
# predict ['005832']
# predict ['005835']
# predict ['005844']
# predict ['005847']
# predict ['005853']
# predict ['005860']
# predict ['005863']
# predict ['005868']
# predict ['005871']
# predict ['005886']
# predict ['005890']
# predict ['005891']
# predict ['005896']
# predict ['005897']
# predict ['005898']
# predict ['005902']
# predict ['005908']
# predict ['005915']
# predict ['005924']
# predict ['005928']
# predict ['005929']
# predict ['005932']
# predict ['005936']
# predict ['005937']
# predict ['005945']
# predict ['005953']
# predict ['005971']
# predict ['005989']
# predict ['006018']
# predict ['006021']
# predict ['006035']
# predict ['006040']
# predict ['006049']
# predict ['006065']
# predict ['006072']
# predict ['006076']
# predict ['006084']
# predict ['006090']
# predict ['006101']
# predict ['006104']
# predict ['006109']
# predict ['006111']
# predict ['006112']
# predict ['006113']
# predict ['006119']
# predict ['006131']
# predict ['006132']
# predict ['006142']
# predict ['006145']
# predict ['006149']
# predict ['006175']
# predict ['006179']
# predict ['006183']
# predict ['006188']
# predict ['006197']
# predict ['006203']
# predict ['006211']
# predict ['006220']
# predict ['006230']
# predict ['006235']
# predict ['006236']
# predict ['006237']
# predict ['006243']
# predict ['006253']
# predict ['006256']
# predict ['006260']
# predict ['006261']
# predict ['006262']
# predict ['006268']
# predict ['006271']
# predict ['006277']
# predict ['006284']
# predict ['006285']
# predict ['006291']
# predict ['006293']
# predict ['006304']
# predict ['006308']
# predict ['006310']
# predict ['006318']
# predict ['006323']
# predict ['006336']
# predict ['006350']
# predict ['006361']
# predict ['006365']
# predict ['006375']
# predict ['006376']
# predict ['006387']
# predict ['006389']
# predict ['006390']
# predict ['006392']
# predict ['006401']
# predict ['006418']
# predict ['006419']
# predict ['006421']
# predict ['006422']
# predict ['006428']
# predict ['006431']
# predict ['006448']
# predict ['006456']
# predict ['006458']
# predict ['006460']
# predict ['006489']
# predict ['006495']
# predict ['006538']
# predict ['006547']
# predict ['006562']
# predict ['006564']
# predict ['006575']
# predict ['006585']
# predict ['006589']
# predict ['006594']
# predict ['006599']
# predict ['006619']
# predict ['006642']
# predict ['006662']
# predict ['006663']
# predict ['006689']
# predict ['006716']
# predict ['006721']
# predict ['006740']
# predict ['006742']
# predict ['006750']
# predict ['006779']
# predict ['006788']
# predict ['006817']
# predict ['006825']
# predict ['006830']
# predict ['006842']
# predict ['006845']
# predict ['006848']
# predict ['006877']
# predict ['006888']
# predict ['006892']
# predict ['006894']
# predict ['006904']
# predict ['006919']
# predict ['006920']
# predict ['006926']
# predict ['006927']
# predict ['006929']
# predict ['006932']
# predict ['006941']
# predict ['006946']
# predict ['006947']
# predict ['006957']
# predict ['006958']
# predict ['006965']
# predict ['006974']
# predict ['006984']
# predict ['006986']
# predict ['006991']
# predict ['007004']
# predict ['007013']
# predict ['007017']
# predict ['007018']
# predict ['007021']
# predict ['007035']
# predict ['007039']
# predict ['007051']
# predict ['007054']
# predict ['007060']
# predict ['007066']
# predict ['007070']
# predict ['007075']
# predict ['007077']
# predict ['007090']
# predict ['007092']
# predict ['007102']
# predict ['007105']
# predict ['007106']
# predict ['007107']
# predict ['007111']
# predict ['007121']
# predict ['007126']
# predict ['007129']
# predict ['007150']
# predict ['007151']
# predict ['007156']
# predict ['007159']
# predict ['007160']
# predict ['007171']
# predict ['007179']
# predict ['007186']
# predict ['007188']
# predict ['007189']
# predict ['007196']
# predict ['007211']
# predict ['007213']
# predict ['007216']
# predict ['007222']
# predict ['007231']
# predict ['007237']
# predict ['007254']
# predict ['007259']
# predict ['007268']
# predict ['007298']
# predict ['007301']
# predict ['007307']
# predict ['007312']
# predict ['007313']
# predict ['007314']
# predict ['007334']
# predict ['007340']
# predict ['007354']
# predict ['007355']
# predict ['007357']
# predict ['007362']
# predict ['007366']
# predict ['007367']
# predict ['007372']
# predict ['007373']
# predict ['007386']
# predict ['007393']
# predict ['007408']
# predict ['007414']
# predict ['007427']
# predict ['007446']

# %%
print(counter)
# Out:
# 1029

# %%
mean_inference = np.mean(total_inference_time)
min_inference = np.min(total_inference_time)
max_inference =np.max(total_inference_time)
var_inference = np.var(total_inference_time)

print('Min: %fs Max: %fs Mean: %fs Var: %fs ' %( min_inference,max_inference,mean_inference,var_inference))
# Out:
# Min: 0.112652s Max: 4.924053s Mean: 0.130404s Var: 0.022467s
